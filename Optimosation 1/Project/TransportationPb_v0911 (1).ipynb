# %% [markdown]
# ### Read the data from the input Excel file

# %%
pip install pulp
# Out:
# Requirement already satisfied: pulp in /Users/mizo/opt/anaconda3/lib/python3.8/site-packages (2.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
inputFileName = "TransportationPb_Data.xlsx"
paramDF = pd.read_excel(inputFileName, "Param", skiprows=0)
supplyDF = pd.read_excel(inputFileName, "Supply", skiprows=0, index_col=0)
demandDF = pd.read_excel(inputFileName, "Demand", skiprows=0, index_col=0)
freightDF = pd.read_excel(inputFileName, "Freight", skiprows=0, index_col=2)

# %% [markdown]
# ### Set the data into dict, easier to manipulate

# %%
plants = supplyDF.to_dict('index')
markets = demandDF.to_dict('index')
   

freightCost = {}  #freightCost[iPlant][iMarket]
for index, row in freightDF.iterrows():
    if row['Plant'] not in freightCost : freightCost[row['Plant']] = {}
    freightCost[row['Plant']][row['Market']] = row['Cost']

# %%
# fct obj : min cost st demands are verfied
from pulp import *
prob = LpProblem("Transportation_problem",LpMinimize)

# %% [markdown]
# ### Add variables

# %%
Xvar = LpVariable.dicts("X", ((i,j) for i in plants for j in markets), 
                             lowBound=0, cat='Continuous')
DemandVar= LpVariable.dicts("Demand", (i for i in markets), lowBound=0, cat='Continuous')
CapacityVar= LpVariable.dicts("Capacity", (i for i in plants), lowBound=0, cat='Continuous')

# %% [markdown]
# ### Add objectives

# %%
prob += lpSum([(freightCost[i][j] + plants[i]['Cost'])* Xvar[i,j] for i in plants for j in markets ])

# %%
#Notre problème renferme 200 variables Xij, 20 contraintes Capa, 10 contraintes de demand

# %%
# for i in plants.keys():
#     for j in markets.keys():
#         print(Xvar[i,j])

# %% [markdown]
# ### Add constraints

# %%
#Capacity constraint (for each plant)
for i in (plants) : 
        prob += lpSum(Xvar[i,j] for j in markets) <= plants[i]['Capacity'] , "capacity[%s]"%(i)

# %%
# # #Demand constraint
for j in (markets) :
    prob += lpSum(Xvar[i,j] for i in plants) >= markets[j]['Demand'] , "demand[%s]"%(j)

# %%
prob
# Out:
# Transportation_problem:
# MINIMIZE
# 19*X_('P1',_'M1') + 22*X_('P1',_'M10') + 17*X_('P1',_'M2') + 18*X_('P1',_'M3') + 19*X_('P1',_'M4') + 22*X_('P1',_'M5') + 16*X_('P1',_'M6') + 17*X_('P1',_'M7') + 15*X_('P1',_'M8') + 16*X_('P1',_'M9') + 13*X_('P10',_'M1') + 16*X_('P10',_'M10') + 14*X_('P10',_'M2') + 12*X_('P10',_'M3') + 16*X_('P10',_'M4') + 18*X_('P10',_'M5') + 17*X_('P10',_'M6') + 14*X_('P10',_'M7') + 14*X_('P10',_'M8') + 18*X_('P10',_'M9') + 14*X_('P11',_'M1') + 10*X_('P11',_'M10') + 9*X_('P11',_'M2') + 13*X_('P11',_'M3') + 13*X_('P11',_'M4') + 10*X_('P11',_'M5') + 12*X_('P11',_'M6') + 14*X_('P11',_'M7') + 12*X_('P11',_'M8') + 7*X_('P11',_'M9') + 29*X_('P12',_'M1') + 26*X_('P12',_'M10') + 30*X_('P12',_'M2') + 32*X_('P12',_'M3') + 23*X_('P12',_'M4') + 28*X_('P12',_'M5') + 28*X_('P12',_'M6') + 27*X_('P12',_'M7') + 26*X_('P12',_'M8') + 26*X_('P12',_'M9') + 34*X_('P13',_'M1') + 32*X_('P13',_'M10') + 32*X_('P13',_'M2') + 31*X_('P13',_'M3') + 35*X_('P13',_'M4') + 33*X_('P13',_'M5') + 27*X_('P13',_'M6') + 27*X_('P13',_'M7') + 30*X_('P13',_'M8') + 28*X_('P13',_'M9') + 27*X_('P14',_'M1') + 24*X_('P14',_'M10') + 27*X_('P14',_'M2') + 23*X_('P14',_'M3') + 20*X_('P14',_'M4') + 28*X_('P14',_'M5') + 22*X_('P14',_'M6') + 22*X_('P14',_'M7') + 25*X_('P14',_'M8') + 23*X_('P14',_'M9') + 29*X_('P15',_'M1') + 33*X_('P15',_'M10') + 35*X_('P15',_'M2') + 33*X_('P15',_'M3') + 32*X_('P15',_'M4') + 29*X_('P15',_'M5') + 32*X_('P15',_'M6') + 33*X_('P15',_'M7') + 32*X_('P15',_'M8') + 29*X_('P15',_'M9') + 19*X_('P16',_'M1') + 13*X_('P16',_'M10') + 17*X_('P16',_'M2') + 21*X_('P16',_'M3') + 17*X_('P16',_'M4') + 17*X_('P16',_'M5') + 13*X_('P16',_'M6') + 21*X_('P16',_'M7') + 17*X_('P16',_'M8') + 19*X_('P16',_'M9') + 28*X_('P17',_'M1') + 26*X_('P17',_'M10') + 25*X_('P17',_'M2') + 26*X_('P17',_'M3') + 24*X_('P17',_'M4') + 28*X_('P17',_'M5') + 29*X_('P17',_'M6') + 31*X_('P17',_'M7') + 23*X_('P17',_'M8') + 24*X_('P17',_'M9') + 23*X_('P18',_'M1') + 26*X_('P18',_'M10') + 27*X_('P18',_'M2') + 22*X_('P18',_'M3') + 23*X_('P18',_'M4') + 24*X_('P18',_'M5') + 21*X_('P18',_'M6') + 24*X_('P18',_'M7') + 23*X_('P18',_'M8') + 24*X_('P18',_'M9') + 24*X_('P19',_'M1') + 29*X_('P19',_'M10') + 24*X_('P19',_'M2') + 23*X_('P19',_'M3') + 22*X_('P19',_'M4') + 23*X_('P19',_'M5') + 28*X_('P19',_'M6') + 28*X_('P19',_'M7') + 22*X_('P19',_'M8') + 29*X_('P19',_'M9') + 17*X_('P2',_'M1') + 11*X_('P2',_'M10') + 17*X_('P2',_'M2') + 9*X_('P2',_'M3') + 18*X_('P2',_'M4') + 10*X_('P2',_'M5') + 12*X_('P2',_'M6') + 13*X_('P2',_'M7') + 15*X_('P2',_'M8') + 10*X_('P2',_'M9') + 21*X_('P20',_'M1') + 21*X_('P20',_'M10') + 25*X_('P20',_'M2') + 24*X_('P20',_'M3') + 18*X_('P20',_'M4') + 19*X_('P20',_'M5') + 22*X_('P20',_'M6') + 19*X_('P20',_'M7') + 25*X_('P20',_'M8') + 18*X_('P20',_'M9') + 30*X_('P3',_'M1') + 29*X_('P3',_'M10') + 34*X_('P3',_'M2') + 36*X_('P3',_'M3') + 30*X_('P3',_'M4') + 29*X_('P3',_'M5') + 37*X_('P3',_'M6') + 33*X_('P3',_'M7') + 34*X_('P3',_'M8') + 31*X_('P3',_'M9') + 31*X_('P4',_'M1') + 34*X_('P4',_'M10') + 34*X_('P4',_'M2') + 36*X_('P4',_'M3') + 36*X_('P4',_'M4') + 29*X_('P4',_'M5') + 31*X_('P4',_'M6') + 32*X_('P4',_'M7') + 36*X_('P4',_'M8') + 33*X_('P4',_'M9') + 27*X_('P5',_'M1') + 21*X_('P5',_'M10') + 21*X_('P5',_'M2') + 25*X_('P5',_'M3') + 22*X_('P5',_'M4') + 21*X_('P5',_'M5') + 22*X_('P5',_'M6') + 22*X_('P5',_'M7') + 29*X_('P5',_'M8') + 26*X_('P5',_'M9') + 15*X_('P6',_'M1') + 9*X_('P6',_'M10') + 17*X_('P6',_'M2') + 17*X_('P6',_'M3') + 17*X_('P6',_'M4') + 12*X_('P6',_'M5') + 9*X_('P6',_'M6') + 13*X_('P6',_'M7') + 12*X_('P6',_'M8') + 11*X_('P6',_'M9') + 6*X_('P7',_'M1') + 10*X_('P7',_'M10') + 12*X_('P7',_'M2') + 14*X_('P7',_'M3') + 15*X_('P7',_'M4') + 11*X_('P7',_'M5') + 14*X_('P7',_'M6') + 12*X_('P7',_'M7') + 6*X_('P7',_'M8') + 14*X_('P7',_'M9') + 26*X_('P8',_'M1') + 24*X_('P8',_'M10') + 23*X_('P8',_'M2') + 24*X_('P8',_'M3') + 26*X_('P8',_'M4') + 20*X_('P8',_'M5') + 21*X_('P8',_'M6') + 27*X_('P8',_'M7') + 26*X_('P8',_'M8') + 28*X_('P8',_'M9') + 35*X_('P9',_'M1') + 33*X_('P9',_'M10') + 33*X_('P9',_'M2') + 31*X_('P9',_'M3') ...
# SUBJECT TO
# capacity_P1_: X_('P1',_'M1') + X_('P1',_'M10') + X_('P1',_'M2')
#  + X_('P1',_'M3') + X_('P1',_'M4') + X_('P1',_'M5') + X_('P1',_'M6')
#  + X_('P1',_'M7') + X_('P1',_'M8') + X_('P1',_'M9') <= 80
#
# capacity_P2_: X_('P2',_'M1') + X_('P2',_'M10') + X_('P2',_'M2')
#  + X_('P2',_'M3') + X_('P2',_'M4') + X_('P2',_'M5') + X_('P2',_'M6')
#  + X_('P2',_'M7') + X_('P2',_'M8') + X_('P2',_'M9') <= 9
#
# capacity_P3_: X_('P3',_'M1') + X_('P3',_'M10') + X_('P3',_'M2')
#  + X_('P3',_'M3') + X_('P3',_'M4') + X_('P3',_'M5') + X_('P3',_'M6')
#  + X_('P3',_'M7') + X_('P3',_'M8') + X_('P3',_'M9') <= 22
#
# capacity_P4_: X_('P4',_'M1') + X_('P4',_'M10') + X_('P4',_'M2')
#  + X_('P4',_'M3') + X_('P4',_'M4') + X_('P4',_'M5') + X_('P4',_'M6')
#  + X_('P4',_'M7') + X_('P4',_'M8') + X_('P4',_'M9') <= 69
#
# capacity_P5_: X_('P5',_'M1') + X_('P5',_'M10') + X_('P5',_'M2')
#  + X_('P5',_'M3') + X_('P5',_'M4') + X_('P5',_'M5') + X_('P5',_'M6')
#  + X_('P5',_'M7') + X_('P5',_'M8') + X_('P5',_'M9') <= 5
#
# capacity_P6_: X_('P6',_'M1') + X_('P6',_'M10') + X_('P6',_'M2')
#  + X_('P6',_'M3') + X_('P6',_'M4') + X_('P6',_'M5') + X_('P6',_'M6')
#  + X_('P6',_'M7') + X_('P6',_'M8') + X_('P6',_'M9') <= 81
#
# capacity_P7_: X_('P7',_'M1') + X_('P7',_'M10') + X_('P7',_'M2')
#  + X_('P7',_'M3') + X_('P7',_'M4') + X_('P7',_'M5') + X_('P7',_'M6')
#  + X_('P7',_'M7') + X_('P7',_'M8') + X_('P7',_'M9') <= 37
#
# capacity_P8_: X_('P8',_'M1') + X_('P8',_'M10') + X_('P8',_'M2')
#  + X_('P8',_'M3') + X_('P8',_'M4') + X_('P8',_'M5') + X_('P8',_'M6')
#  + X_('P8',_'M7') + X_('P8',_'M8') + X_('P8',_'M9') <= 18
#
# capacity_P9_: X_('P9',_'M1') + X_('P9',_'M10') + X_('P9',_'M2')
#  + X_('P9',_'M3') + X_('P9',_'M4') + X_('P9',_'M5') + X_('P9',_'M6')
#  + X_('P9',_'M7') + X_('P9',_'M8') + X_('P9',_'M9') <= 53
#
# capacity_P10_: X_('P10',_'M1') + X_('P10',_'M10') + X_('P10',_'M2')
#  + X_('P10',_'M3') + X_('P10',_'M4') + X_('P10',_'M5') + X_('P10',_'M6')
#  + X_('P10',_'M7') + X_('P10',_'M8') + X_('P10',_'M9') <= 2
#
# capacity_P11_: X_('P11',_'M1') + X_('P11',_'M10') + X_('P11',_'M2')
#  + X_('P11',_'M3') + X_('P11',_'M4') + X_('P11',_'M5') + X_('P11',_'M6')
#  + X_('P11',_'M7') + X_('P11',_'M8') + X_('P11',_'M9') <= 56
#
# capacity_P12_: X_('P12',_'M1') + X_('P12',_'M10') + X_('P12',_'M2')
#  + X_('P12',_'M3') + X_('P12',_'M4') + X_('P12',_'M5') + X_('P12',_'M6')
#  + X_('P12',_'M7') + X_('P12',_'M8') + X_('P12',_'M9') <= 90
#
# capacity_P13_: X_('P13',_'M1') + X_('P13',_'M10') + X_('P13',_'M2')
#  + X_('P13',_'M3') + X_('P13',_'M4') + X_('P13',_'M5') + X_('P13',_'M6')
#  + X_('P13',_'M7') + X_('P13',_'M8') + X_('P13',_'M9') <= 67
#
# capacity_P14_: X_('P14',_'M1') + X_('P14',_'M10') + X_('P14',_'M2')
#  + X_('P14',_'M3') + X_('P14',_'M4') + X_('P14',_'M5') + X_('P14',_'M6')
#  + X_('P14',_'M7') + X_('P14',_'M8') + X_('P14',_'M9') <= 45
#
# capacity_P15_: X_('P15',_'M1') + X_('P15',_'M10') + X_('P15',_'M2')
#  + X_('P15',_'M3') + X_('P15',_'M4') + X_('P15',_'M5') + X_('P15',_'M6')
#  + X_('P15',_'M7') + X_('P15',_'M8') + X_('P15',_'M9') <= 56
#
# capacity_P16_: X_('P16',_'M1') + X_('P16',_'M10') + X_('P16',_'M2')
#  + X_('P16',_'M3') + X_('P16',_'M4') + X_('P16',_'M5') + X_('P16',_'M6')
#  + X_('P16',_'M7') + X_('P16',_'M8') + X_('P16',_'M9') <= 49
#
# capacity_P17_: X_('P17',_'M1') + X_('P17',_'M10') + X_('P17',_'M2')
#  + X_('P17',_'M3') + X_('P17',_'M4') + X_('P17',_'M5') + X_('P17',_'M6')
#  + X_('P17',_'M7') + X_('P17',_'M8') + X_('P17',_'M9') <= 1
#
# capacity_P18_: X_('P18',_'M1') + X_('P18',_'M10') + X_('P18',_'M2')
#  + X_('P18',_'M3') + X_('P18',_'M4') + X_('P18',_'M5') + X_('P18',_'M6')
#  + X_('P18',_'M7') + X_('P18',_'M8') + X_('P18',_'M9') <= 96
#
# capacity_P19_: X_('P19',_'M1') + X_('P19',_'M10') + X_('P19',_'M2')
#  + X_('P19',_'M3') + X_('P19',_'M4') + X_('P19',_'M5') + X_('P19',_'M6')
#  + X_('P19',_'M7') + X_('P19',_'M8') + X_('P19',_'M9') <= 83
#
# capacity_P20_: X_('P20',_'M1') + X_('P20',_'M10') + X_('P20',_'M2')
#  + X_('P20',_'M3') + X_('P20',_'M4') + X_('P20',_'M5') + X_('P20',_'M6')
#  + X_('P20',_'M7') + X_('P20',_'M8') + X_('P20',_'M9') <= 26
#
# demand_M1_: X_('P1',_'M1') + X_('P10',_'M1') + X_('P11',_'M1')
#  + X_('P12',_'M1') + X_('P13',_'M1') + X_('P14',_'M1') + X_('P15',_'M1')
#  + X_('P16',_'M1') + X_('P17',_'M1') + X_('P18',_'M1') + X_('P19',_'M1')
#  + X_('P2',_'M1') + X_('P20',_'M1') + X_('P3',_'M1') + X_('P4',_'M1')
#  + X_('P5',_'M1') + X_('P6',_'M1') + X_('P7',_'M1') + X_('P8',_'M1')
#  + X_('P9',_'M1') >= 38
#
# demand_M2_: X_('P1',_'M2') + X_('P10',_'M2') + X_('P11',_'M2')
#  + X_('P12',_'M2') + X_('P13',_'M2') + X_('P14',_'M2') + X_('P15',_'M2')
#  + X_('P16',_'M2') + X_('P17',_'M2') + X_('P18',_'M2') + X_('P19',_'M2')
#  + X_('P2',_'M2') + X_('P20',_'M2') + X_('P3',_'M2') + X_('P4',_'M2')
#  + X_('P5',_'M2') + X_('P6',_'M2') + X_('P7',_'M2') + X_('P8',_'M2')
#  + X_('P9',_'M2') >= 129
#
# demand_M3_: X_('P1',_'M3') + X_('P10',_'M3') + X_('P11',_'M3')
#  + X_('P12',_'M3') + X_('P13',_'M3') + X_('P14',_'M3') + X_('P15',_'M3')
#  + X_('P16',_'M3') + X_('P17',_'M3') + X_('P18',_'M3') + X_('P19',_'M3')
#  + X_('P2',_'M3') + X_('P20',_'M3') + X_('P3',_'M3') + X_('P4',_'M3')
#  + X_('P5',_'M3') + X_('P6',_'M3') + X_('P7',_'M3') + X_('P8',_'M3')
#  + X_('P9',_'M3') >= 104
#
# demand_M4_: X_('P1',_'M4') + X_('P10',_'M4') + X_('P11',_'M4')
#  + X_('P12',_'M4') + X_('P13',_'M4') + X_('P14',_'M4') + X_('P15',_'M4')
#  + X_('P16',_'M4') + X_('P17',_'M4') + X_('P18',_'M4') + X_('P19',_'M4')
#  + X_('P2',_'M4') + X_('P20',_'M4') + X_('P3',_'M4') + X_('P4',_'M4')
#  + X_('P5',_'M4') + X_('P6',_'M4') + X_('P7',_'M4') + X_('P8',_'M4')
#  + X_('P9',_'M4') >= 75
#
# demand_M5_: X_('P1',_'M5') + X_('P10',_'M5') + X_('P11',_'M5')
#  + X_('P12',_'M5') + X_('P13',_'M5') + X_('P14',_'M5') + X_('P15',_'M5')
#  + X_('P16',_'M5') + X_('P17',_'M5') + X_('P18',_'M5') + X_('P19',_'M5')
#  + X_('P2',_'M5') + X_('P20',_'M5') + X_('P3',_'M5') + X_('P4',_'M5')
#  + X_('P5',_'M5') + X_('P6',_'M5') + X_('P7',_'M5') + X_('P8',_'M5')
#  + X_('P9',_'M5') >= 126
#
# demand_M6_: X_('P1',_'M6') + X_('P10',_'M6') + X_('P11',_'M6')
#  + X_('P12',_'M6') + X_('P13',_'M6') + X_('P14',_'M6') + X_('P15',_'M6')
#  + X_('P16',_'M6') + X_('P17',_'M6') + X_('P18',_'M6') + X_('P19',_'M6')
#  + X_('P2',_'M6') + X_('P20',_'M6') + X_('P3',_'M6') + X_('P4',_'M6')
#  + X_('P5',_'M6') + X_('P6',_'M6') + X_('P7',_'M6') + X_('P8',_'M6')
#  + X_('P9',_'M6') >= 90
#
# demand_M7_: X_('P1',_'M7') + X_('P10',_'M7') + X_('P11',_'M7')
#  + X_('P12',_'M7') + X_('P13',_'M7') + X_('P14',_'M7') + X_('P15',_'M7')
#  + X_('P16',_'M7') + X_('P17',_'M7') + X_('P18',_'M7') + X_('P19',_'M7')
#  + X_('P2',_'M7') + X_('P20',_'M7') + X_('P3',_'M7') + X_('P4',_'M7')
#  + X_('P5',_'M7') + X_('P6',_'M7') + X_('P7',_'M7') + X_('P8',_'M7')
#  + X_('P9',_'M7') >= 105
#
# demand_M8_: X_('P1',_'M8') + X_('P10',_'M8') + X_('P11',_'M8')
#  + X_('P12',_'M8') + X_('P13',_'M8') + X_('P14',_'M8') + X_('P15',_'M8')
#  + X_('P16',_'M8') + X_('P17',_'M8') + X_('P18',_'M8') + X_('P19',_'M8')
#  + X_('P2',_'M8') + X_('P20',_'M8') + X_('P3',_'M8') + X_('P4',_'M8')
#  + X_('P5',_'M8') + X_('P6',_'M8') + X_('P7',_'M8') + X_('P8',_'M8')
#  + X_('P9',_'M8') >= 91
#
# demand_M9_: X_('P1',_'M9') + X_('P10',_'M9') + X_('P11',_'M9')
#  + X_('P12',_'M9') + X_('P13',_'M9') + X_('P14',_'M9') + X_('P15',_'M9')
#  + X_('P16',_'M9') + X_('P17',_'M9') + X_('P18',_'M9') + X_('P19',_'M9')
#  + X_('P2',_'M9') + X_('P20',_'M9') + X_('P3',_'M9') + X_('P4',_'M9')
#  + X_('P5',_'M9') + X_('P6',_'M9') + X_('P7',_'M9') + X_('P8',_'M9')
#  + X_('P9',_'M9') >= 47
#
# demand_M10_: X_('P1',_'M10') + X_('P10',_'M10') + X_('P11',_'M10')
#  + X_('P12',_'M10') + X_('P13',_'M10') + X_('P14',_'M10') + X_('P15',_'M10')
#  + X_('P16',_'M10') + X_('P17',_'M10') + X_('P18',_'M10') + X_('P19',_'M10')
#  + X_('P2',_'M10') + X_('P20',_'M10') + X_('P3',_'M10') + X_('P4',_'M10')
#  + X_('P5',_'M10') + X_('P6',_'M10') + X_('P7',_'M10') + X_('P8',_'M10')
#  + X_('P9',_'M10') >= 61
#
# VARIABLES
# X_('P1',_'M1') Continuous
# X_('P1',_'M10') Continuous
# X_('P1',_'M2') Continuous
# X_('P1',_'M3') Continuous
# X_('P1',_'M4') Continuous
# X_('P1',_'M5') Continuous
# X_('P1',_'M6') Continuous
# X_('P1',_'M7') Continuous
# X_('P1',_'M8') Continuous
# X_('P1',_'M9') Continuous
# X_('P10',_'M1') Continuous
# X_('P10',_'M10') Continuous
# X_('P10',_'M2') Continuous
# X_('P10',_'M3') Continuous
# X_('P10',_'M4') Continuous
# X_('P10',_'M5') Continuous
# X_('P10',_'M6') Continuous
# X_('P10',_'M7') Continuous
# X_('P10',_'M8') Continuous
# X_('P10',_'M9') Continuous
# X_('P11',_'M1') Continuous
# X_('P11',_'M10') Continuous
# X_('P11',_'M2') Continuous
# X_('P11',_'M3') Continuous
# X_('P11',_'M4') Continuous
# X_('P11',_'M5') Continuous
# X_('P11',_'M6') Continuous
# X_('P11',_'M7') Continuous
# X_('P11',_'M8') Continuous
# X_('P11',_'M9') Continuous
# X_('P12',_'M1') Continuous
# X_('P12',_'M10') Continuous
# X_('P12',_'M2') Continuous
# X_('P12',_'M3') Continuous
# X_('P12',_'M4') Continuous
# X_('P12',_'M5') Continuous
# X_('P12',_'M6') Continuous
# X_('P12',_'M7') Continuous
# X_('P12',_'M8') Continuous
# X_('P12',_'M9') Continuous
# X_('P13',_'M1') Continuous
# X_('P13',_'M10') Continuous
# X_('P13',_'M2') Continuous
# X_('P13',_'M3') Continuous
# X_('P13',_'M4') Continuous
# X_('P13',_'M5') Continuous
# X_('P13',_'M6') Continuous
# X_('P13',_'M7') Continuous
# X_('P13',_'M8') Continuous
# X_('P13',_'M9') Continuous
# X_('P14',_'M1') Continuous
# X_('P14',_'M10') Continuous
# X_('P14',_'M2') Continuous
# X_('P14',_'M3') Continuous
# X_('P14',_'M4') Continuous
# X_('P14',_'M5') Continuous
# X_('P14',_'M6') Continuous
# X_('P14',_'M7') Continuous
# X_('P14',_'M8') Continuous
# X_('P14',_'M9') Continuous
# X_('P15',_'M1') Continuous
# X_('P15',_'M10') Continuous
# X_('P15',_'M2') Continuous
# X_('P15',_'M3') Continuous
# X_('P15',_'M4') Continuous
# X_('P15',_'M5') Continuous
# X_('P15',_'M6') Continuous
# X_('P15',_'M7') Continuous
# X_('P15',_'M8') Continuous
# X_('P15',_'M9') Continuous
# X_('P16',_'M1') Continuous
# X_('P16',_'M10') Continuous
# X_('P16',_'M2') Continuous
# X_('P16',_'M3') Continuous
# X_('P16',_'M4') Continuous
# X_('P16',_'M5') Continuous
# X_('P16',_'M6') Continuous
# X_('P16',_'M7') Continuous
# X_('P16',_'M8') Continuous
# X_('P16',_'M9') Continuous
# X_('P17',_'M1') Continuous
# X_('P17',_'M10') Continuous
# X_('P17',_'M2') Continuous
# X_('P17',_'M3') Continuous
# X_('P17',_'M4') Continuous
# X_('P17',_'M5') Continuous
# X_('P17',_'M6') Continuous
# X_('P17',_'M7') Continuous
# X_('P17',_'M8') Continuous
# X_('P17',_'M9') Continuous
# X_('P18',_'M1') Continuous
# X_('P18',_'M10') Continuous
# X_('P18',_'M2') Continuous
# X_('P18',_'M3') Continuous
# X_('P18',_'M4') Continuous
# X_('P18',_'M5') Continuous
# X_('P18',_'M6') Continuous
# X_('P18',_'M7') Continuous
# X_('P18',_'M8') Continuous
# X_('P18',_'M9') Continuous
# X_('P19',_'M1') Continuous
# X_('P19',_'M10') Continuous
# X_('P19',_'M2') Continuous
# X_('P19',_'M3') Continuous
# X_('P19',_'M4') Continuous
# X_('P19',_'M5') Continuous
# X_('P19',_'M6') Continuous
# X_('P19',_'M7') Continuous
# X_('P19',_'M8') Continuous
# X_('P19',_'M9') Continuous
# X_('P2',_'M1') Continuous
# X_('P2',_'M10') Continuous
# X_('P2',_'M2') Continuous
# X_('P2',_'M3') Continuous
# X_('P2',_'M4') Continuous
# X_('P2',_'M5') Continuous
# X_('P2',_'M6') Continuous
# X_('P2',_'M7') Continuous
# X_('P2',_'M8') Continuous
# X_('P2',_'M9') Continuous
# X_('P20',_'M1') Continuous
# X_('P20',_'M10') Continuous
# X_('P20',_'M2') Continuous
# X_('P20',_'M3') Continuous
# X_('P20',_'M4') Continuous
# X_('P20',_'M5') Continuous
# X_('P20',_'M6') Continuous
# X_('P20',_'M7') Continuous
# X_('P20',_'M8') Continuous
# X_('P20',_'M9') Continuous
# X_('P3',_'M1') Continuous
# X_('P3',_'M10') Continuous
# X_('P3',_'M2') Continuous
# X_('P3',_'M3') Continuous
# X_('P3',_'M4') Continuous
# X_('P3',_'M5') Continuous
# X_('P3',_'M6') Continuous
# X_('P3',_'M7') Continuous
# X_('P3',_'M8') Continuous
# X_('P3',_'M9') Continuous
# X_('P4',_'M1') Continuous
# X_('P4',_'M10') Continuous
# X_('P4',_'M2') Continuous
# X_('P4',_'M3') Continuous
# X_('P4',_'M4') Continuous
# X_('P4',_'M5') Continuous
# X_('P4',_'M6') Continuous
# X_('P4',_'M7') Continuous
# X_('P4',_'M8') Continuous
# X_('P4',_'M9') Continuous
# X_('P5',_'M1') Continuous
# X_('P5',_'M10') Continuous
# X_('P5',_'M2') Continuous
# X_('P5',_'M3') Continuous
# X_('P5',_'M4') Continuous
# X_('P5',_'M5') Continuous
# X_('P5',_'M6') Continuous
# X_('P5',_'M7') Continuous
# X_('P5',_'M8') Continuous
# X_('P5',_'M9') Continuous
# X_('P6',_'M1') Continuous
# X_('P6',_'M10') Continuous
# X_('P6',_'M2') Continuous
# X_('P6',_'M3') Continuous
# X_('P6',_'M4') Continuous
# X_('P6',_'M5') Continuous
# X_('P6',_'M6') Continuous
# X_('P6',_'M7') Continuous
# X_('P6',_'M8') Continuous
# X_('P6',_'M9') Continuous
# X_('P7',_'M1') Continuous
# X_('P7',_'M10') Continuous
# X_('P7',_'M2') Continuous
# X_('P7',_'M3') Continuous
# X_('P7',_'M4') Continuous
# X_('P7',_'M5') Continuous
# X_('P7',_'M6') Continuous
# X_('P7',_'M7') Continuous
# X_('P7',_'M8') Continuous
# X_('P7',_'M9') Continuous
# X_('P8',_'M1') Continuous
# X_('P8',_'M10') Continuous
# X_('P8',_'M2') Continuous
# X_('P8',_'M3') Continuous
# X_('P8',_'M4') Continuous
# X_('P8',_'M5') Continuous
# X_('P8',_'M6') Continuous
# X_('P8',_'M7') Continuous
# X_('P8',_'M8') Continuous
# X_('P8',_'M9') Continuous
# X_('P9',_'M1') Continuous
# X_('P9',_'M10') Continuous
# X_('P9',_'M2') Continuous
# X_('P9',_'M3') Continuous
# X_('P9',_'M4') Continuous
# X_('P9',_'M5') Continuous
# X_('P9',_'M6') Continuous
# X_('P9',_'M7') Continuous
# X_('P9',_'M8') Continuous
# X_('P9',_'M9') Continuous

# %%
#prob.writeLP("blenderProblem.lp", writeSOS=1, mip=1)
prob.solve()
print("Status:", LpStatus[prob.status])
print ("Objective = ", value(prob.objective))
varsDict = {}
for v in prob.variables():
    varsDict[v.name] = v.varValue
    if "X" in v.name:
        print(v.name, "=", v.varValue)
# Out:
# Status: Optimal
# Objective =  16847.0
# X_('P1',_'M1') = 0.0
# X_('P1',_'M10') = 0.0
# X_('P1',_'M2') = 80.0
# X_('P1',_'M3') = 0.0
# X_('P1',_'M4') = 0.0
# X_('P1',_'M5') = 0.0
# X_('P1',_'M6') = 0.0
# X_('P1',_'M7') = 0.0
# X_('P1',_'M8') = 0.0
# X_('P1',_'M9') = 0.0
# X_('P10',_'M1') = 0.0
# X_('P10',_'M10') = 0.0
# X_('P10',_'M2') = 0.0
# X_('P10',_'M3') = 2.0
# X_('P10',_'M4') = 0.0
# X_('P10',_'M5') = 0.0
# X_('P10',_'M6') = 0.0
# X_('P10',_'M7') = 0.0
# X_('P10',_'M8') = 0.0
# X_('P10',_'M9') = 0.0
# X_('P11',_'M1') = 0.0
# X_('P11',_'M10') = 0.0
# X_('P11',_'M2') = 44.0
# X_('P11',_'M3') = 0.0
# X_('P11',_'M4') = 0.0
# X_('P11',_'M5') = 0.0
# X_('P11',_'M6') = 0.0
# X_('P11',_'M7') = 0.0
# X_('P11',_'M8') = 0.0
# X_('P11',_'M9') = 12.0
# X_('P12',_'M1') = 0.0
# X_('P12',_'M10') = 0.0
# X_('P12',_'M2') = 0.0
# X_('P12',_'M3') = 0.0
# X_('P12',_'M4') = 75.0
# X_('P12',_'M5') = 0.0
# X_('P12',_'M6') = 0.0
# X_('P12',_'M7') = 0.0
# X_('P12',_'M8') = 7.0
# X_('P12',_'M9') = 8.0
# X_('P13',_'M1') = 0.0
# X_('P13',_'M10') = 0.0
# X_('P13',_'M2') = 0.0
# X_('P13',_'M3') = 0.0
# X_('P13',_'M4') = 0.0
# X_('P13',_'M5') = 0.0
# X_('P13',_'M6') = 0.0
# X_('P13',_'M7') = 67.0
# X_('P13',_'M8') = 0.0
# X_('P13',_'M9') = 0.0
# X_('P14',_'M1') = 0.0
# X_('P14',_'M10') = 0.0
# X_('P14',_'M2') = 0.0
# X_('P14',_'M3') = 0.0
# X_('P14',_'M4') = 0.0
# X_('P14',_'M5') = 0.0
# X_('P14',_'M6') = 7.0
# X_('P14',_'M7') = 38.0
# X_('P14',_'M8') = 0.0
# X_('P14',_'M9') = 0.0
# X_('P15',_'M1') = 1.0
# X_('P15',_'M10') = 0.0
# X_('P15',_'M2') = 0.0
# X_('P15',_'M3') = 0.0
# X_('P15',_'M4') = 0.0
# X_('P15',_'M5') = 39.0
# X_('P15',_'M6') = 0.0
# X_('P15',_'M7') = 0.0
# X_('P15',_'M8') = 0.0
# X_('P15',_'M9') = 1.0
# X_('P16',_'M1') = 0.0
# X_('P16',_'M10') = 0.0
# X_('P16',_'M2') = 0.0
# X_('P16',_'M3') = 0.0
# X_('P16',_'M4') = 0.0
# X_('P16',_'M5') = 0.0
# X_('P16',_'M6') = 49.0
# X_('P16',_'M7') = 0.0
# X_('P16',_'M8') = 0.0
# X_('P16',_'M9') = 0.0
# X_('P17',_'M1') = 0.0
# X_('P17',_'M10') = 0.0
# X_('P17',_'M2') = 0.0
# X_('P17',_'M3') = 0.0
# X_('P17',_'M4') = 0.0
# X_('P17',_'M5') = 0.0
# X_('P17',_'M6') = 0.0
# X_('P17',_'M7') = 0.0
# X_('P17',_'M8') = 1.0
# X_('P17',_'M9') = 0.0
# X_('P18',_'M1') = 0.0
# X_('P18',_'M10') = 0.0
# X_('P18',_'M2') = 0.0
# X_('P18',_'M3') = 93.0
# X_('P18',_'M4') = 0.0
# X_('P18',_'M5') = 0.0
# X_('P18',_'M6') = 3.0
# X_('P18',_'M7') = 0.0
# X_('P18',_'M8') = 0.0
# X_('P18',_'M9') = 0.0
# X_('P19',_'M1') = 0.0
# X_('P19',_'M10') = 0.0
# X_('P19',_'M2') = 0.0
# X_('P19',_'M3') = 0.0
# X_('P19',_'M4') = 0.0
# X_('P19',_'M5') = 0.0
# X_('P19',_'M6') = 0.0
# X_('P19',_'M7') = 0.0
# X_('P19',_'M8') = 83.0
# X_('P19',_'M9') = 0.0
# X_('P2',_'M1') = 0.0
# X_('P2',_'M10') = 0.0
# X_('P2',_'M2') = 0.0
# X_('P2',_'M3') = 9.0
# X_('P2',_'M4') = 0.0
# X_('P2',_'M5') = 0.0
# X_('P2',_'M6') = 0.0
# X_('P2',_'M7') = 0.0
# X_('P2',_'M8') = 0.0
# X_('P2',_'M9') = 0.0
# X_('P20',_'M1') = 0.0
# X_('P20',_'M10') = 0.0
# X_('P20',_'M2') = 0.0
# X_('P20',_'M3') = 0.0
# X_('P20',_'M4') = 0.0
# X_('P20',_'M5') = 0.0
# X_('P20',_'M6') = 0.0
# X_('P20',_'M7') = 0.0
# X_('P20',_'M8') = 0.0
# X_('P20',_'M9') = 26.0
# X_('P3',_'M1') = 0.0
# X_('P3',_'M10') = 11.0
# X_('P3',_'M2') = 0.0
# X_('P3',_'M3') = 0.0
# X_('P3',_'M4') = 0.0
# X_('P3',_'M5') = 0.0
# X_('P3',_'M6') = 0.0
# X_('P3',_'M7') = 0.0
# X_('P3',_'M8') = 0.0
# X_('P3',_'M9') = 0.0
# X_('P4',_'M1') = 0.0
# X_('P4',_'M10') = 0.0
# X_('P4',_'M2') = 0.0
# X_('P4',_'M3') = 0.0
# X_('P4',_'M4') = 0.0
# X_('P4',_'M5') = 69.0
# X_('P4',_'M6') = 0.0
# X_('P4',_'M7') = 0.0
# X_('P4',_'M8') = 0.0
# X_('P4',_'M9') = 0.0
# X_('P5',_'M1') = 0.0
# X_('P5',_'M10') = 0.0
# X_('P5',_'M2') = 5.0
# X_('P5',_'M3') = 0.0
# X_('P5',_'M4') = 0.0
# X_('P5',_'M5') = 0.0
# X_('P5',_'M6') = 0.0
# X_('P5',_'M7') = 0.0
# X_('P5',_'M8') = 0.0
# X_('P5',_'M9') = 0.0
# X_('P6',_'M1') = 0.0
# X_('P6',_'M10') = 50.0
# X_('P6',_'M2') = 0.0
# X_('P6',_'M3') = 0.0
# X_('P6',_'M4') = 0.0
# X_('P6',_'M5') = 0.0
# X_('P6',_'M6') = 31.0
# X_('P6',_'M7') = 0.0
# X_('P6',_'M8') = 0.0
# X_('P6',_'M9') = 0.0
# X_('P7',_'M1') = 37.0
# X_('P7',_'M10') = 0.0
# X_('P7',_'M2') = 0.0
# X_('P7',_'M3') = 0.0
# X_('P7',_'M4') = 0.0
# X_('P7',_'M5') = 0.0
# X_('P7',_'M6') = 0.0
# X_('P7',_'M7') = 0.0
# X_('P7',_'M8') = 0.0
# X_('P7',_'M9') = 0.0
# X_('P8',_'M1') = 0.0
# X_('P8',_'M10') = 0.0
# X_('P8',_'M2') = 0.0
# X_('P8',_'M3') = 0.0
# X_('P8',_'M4') = 0.0
# X_('P8',_'M5') = 18.0
# X_('P8',_'M6') = 0.0
# X_('P8',_'M7') = 0.0
# X_('P8',_'M8') = 0.0
# X_('P8',_'M9') = 0.0
# X_('P9',_'M1') = 0.0
# X_('P9',_'M10') = 0.0
# X_('P9',_'M2') = 0.0
# X_('P9',_'M3') = 0.0
# X_('P9',_'M4') = 0.0
# X_('P9',_'M5') = 0.0
# X_('P9',_'M6') = 0.0
# X_('P9',_'M7') = 0.0
# X_('P9',_'M8') = 0.0
# X_('P9',_'M9') = 0.0

# %% [markdown]
# Problème Dual

# %% [markdown]
# #Le nombre de variables du pb dual = nb de contraintes du primal
#
# ```
# # Ce texte est au format code
# ```

# %%
for name, c in list(prob.constraints.items()):
     if "capacity" in name or "demand" in name:
        print(name, ":", c.pi, "\t\t", c.slack)
# Out:
# capacity_P1_ : -14.0 		 -0.0
# capacity_P2_ : -21.0 		 -0.0
# capacity_P3_ : 0.0 		 11.0
# capacity_P4_ : 0.0 		 -0.0
# capacity_P5_ : -10.0 		 -0.0
# capacity_P6_ : -20.0 		 -0.0
# capacity_P7_ : -23.0 		 -0.0
# capacity_P8_ : -9.0 		 -0.0
# capacity_P9_ : 0.0 		 53.0
# capacity_P10_ : -18.0 		 -0.0
# capacity_P11_ : -22.0 		 -0.0
# capacity_P12_ : -3.0 		 -0.0
# capacity_P13_ : -2.0 		 -0.0
# capacity_P14_ : -7.0 		 -0.0
# capacity_P15_ : 0.0 		 15.0
# capacity_P16_ : -16.0 		 -0.0
# capacity_P17_ : -6.0 		 -0.0
# capacity_P18_ : -8.0 		 -0.0
# capacity_P19_ : -7.0 		 -0.0
# capacity_P20_ : -11.0 		 -0.0
# demand_M1_ : 29.0 		 -0.0
# demand_M2_ : 31.0 		 -0.0
# demand_M3_ : 30.0 		 -0.0
# demand_M4_ : 26.0 		 -0.0
# demand_M5_ : 29.0 		 -0.0
# demand_M6_ : 29.0 		 -0.0
# demand_M7_ : 29.0 		 -0.0
# demand_M8_ : 29.0 		 -0.0
# demand_M9_ : 29.0 		 -0.0
# demand_M10_ : 29.0 		 -0.0

# %%
# # #New constraint
for i in (plants) :
  for j in (markets) :
    prob += Xvar[i,j]  <= 0.5 * markets[j]['Demand'] , "NewCinstarints plant[%s] market[%s]"%(i,j)
