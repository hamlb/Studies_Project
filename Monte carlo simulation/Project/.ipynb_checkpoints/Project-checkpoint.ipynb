# %% [markdown]
# # Project Monte Carlo

# %% [markdown]
# ### Initiation

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
from scipy.stats import beta 
import scipy.stats as sps
import sympy as sp

# %% [markdown]
# lets start by simulating the geometric brownian mouvement

# %%
#Defining the brownian motion :
def BM(N,dt): 
    W = np.zeros(N)
    for i in range(N-1):
        dW = np.sqrt(dt[i])* np.random.randn(1)
        W[i+1] = W[i] + dW        #Brownian path
    return W

def GBM(X_0, sigma, W, N, t):
    X = []
    X.append(X_0)     
    for i in range(1,N):
        Xi = X_0 * np.exp(sigma * W[i]  + (-0.5 * sigma**2) *t[i])
        X.append(Xi)   
    return X


X_0= 104.6
sigma = 0.2 
N = 3 #number of steps
dt = np.array([1, 5])  
W = BM(N,dt)
t2 = 6   
t = np.array([0, 1, 6])

#the brownian motion is. :
s=GBM(X_0,sigma,W,N,t)
s
# Out:
# [104.6, 75.04157680351291, 52.79308036563539]

# %%
#Simulating f1 and f2

t = np.array([0, 1, 6])
X0 = 104.6
sigma = 0.2
dt = [1, 5]
M = 100
N_i = 200

#Crearing the 

W1 = np.zeros(M)
W2 = np.zeros(N_i)
X1 = np.zeros(M)
X2 = np.zeros((M,N_i))

# gaussian N(0,1)
g = np.random.randn(M)
# Generate the Brownian increment using g
dW = np.sqrt(dt[0]) * g
# Update the Brownian trajectory recursively
W1 = W1 + dW
X1 = X0 * np.exp(sigma * W1 - sigma**2*t[1]/2)
for i in range(M):
    g = np.random.randn(N_i)
    dW = np.sqrt(dt[1]) * g
    W2 = W1[i] + dW
    X2[i,:] = X0 * np.exp(sigma * W2 - sigma**2*t[2]/2)
    
X2_res=X2
X1_res=X1
X0 = np.repeat(X0, N_i*M)
X1 = np.repeat(X1, N_i)
X2 = X2.flatten()
X0 = X0[:, np.newaxis]
X1 = X1[:, np.newaxis]
X2 = X2[:, np.newaxis]
Matrix = np.concatenate((X0, X1, X2), axis=1)



plt.plot(t, Matrix.T)
plt.title("X Simulation, M = {0} , N_i={1}".format(M,N_i))
X2=X2_res
X1=X1_res

# %%
#Simulate q

# %%
q_0=100
a=2.36
b=4.15
c = 7.76

B=np.random.beta(a,b,size=(M,N_i))
Q=q_0*(1+B)

# %%
#defining f1 and f2

# %%
def f1(x):
    return q_0*(x - c)
 
def f2(X2, Q):
    return Q*X2 - 2.5 * c * (q_0+Q)

# %%
#identifying u1
u1=np.mean(f2(X2, Q),axis=1)

#plotting U_1
plt.hist(u1)
plt.title('Values of the expected payoff U_1', fontsize='10')
plt.show()

# %%
Gain_X1=np.maximum((u1-f1(X1)),0)

# Plotting Gain_X1

plt.figure(figsize=(5,5))
plt.hist(Gain_X1)
plt.xlabel('Gain exceedance')
plt.ylabel('Frequency')

plt.title('Distribution of the gain exceedance at time t1', fontsize='12')

plt.show()

Gain_0=Gain.mean()

print(Gain_0)
# Out:
# 372.0673433594656

# %%
# Plotting positive set points
plt.figure(figsize=(10,5))
plt.scatter(X1,Gain_X1, marker='.')
plt.plot(X1, np.zeros(M), color="red" , label="f1")
plt.title('Positive Set Points', fontsize='12')
plt.xlabel('X1')
plt.ylabel('Gain')

plt.show()
print("The positive set is given by the following array: ")
print(X1)
# Out:
# The positive set is given by the following array:
# [ 73.29481791  78.3410973  113.91054623  89.26899949 102.67733003
#  108.77940463  96.2622718   95.29366657 134.7506175  134.59080738
#  148.02114282  96.76598339 124.61904148 120.3150562   71.3717885
#   88.44291618 110.18807306 162.6643282  128.64696177  86.42639279
#  138.87687926  84.52288037 123.55604799 125.96551892  88.03810702
#  133.47126696  86.88974258  98.03245588 137.40494752 102.84964108
#   74.34668172 144.16747499 106.19706686 114.52787819  90.79142978
#   95.46055982  82.50280357 115.90566543  83.14985053 119.50725413
#  100.28471908 105.6616368   65.19886429 139.30200525  99.03971611
#  101.72860441 136.90345816 124.11686873 105.74463706  72.6442005
#  115.039654    65.96022656 146.93670397  96.85787399 107.71949104
#  104.87312438  94.3688003  123.0657074  127.09940143  81.60281104
#  140.19779072 105.03609177  90.23437174  90.28514869  77.17934528
#   95.66559756 113.01869348 117.04814823 113.58840373 118.61781719
#  115.19138495 105.1038901  120.71424425 119.12830188 148.61110586
#  106.02632739 112.95676036  75.05794011  84.8758092  119.1917533
#   86.3864886   87.49684454 120.8590525   92.03289066  96.67297013
#  100.19554647  68.20878375 101.16020632  78.43590473 123.02312244
#  140.70053391  97.72212943  95.40902073 120.57754424 127.51184216
#   86.39081265 130.48730556  99.09045991  91.592515    79.02246967]
